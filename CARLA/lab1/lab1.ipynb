# %% [markdown]
# # Automatyka Pojazdowa - laboratorium 1
#
# Celem tego laboratorium jest zapoznanie z otwartoźródłowym środowiskiem [CARLA](https://carla.org/), służącym do symulacji scenariuszy ruchu pojazdów autonomicznych. W trakcie laboratoriów będziemy korzystać ze środowiska CARLA 0.9.15.
#
# Środowisko to pozwala na symulację end-to-end planowania, sterowania, percepcji oraz koordynacji pojazdów w kontrolowanym środowisku, które pozwala na dowolną konfigurację warunków pogodowych, ruchu drogowego czy kształtu środowiska (jezdnia, pasy, przeszkody, otoczenie).

# %% [markdown]
# ## Pobieranie plików
# W celu pobrania niezbędnych do realizacji ćwiczenia plików należy z materiałów dodatkowych pobrać i zapisać skrypt `clone_carla.sh`. Następnie należy wykonać następujące polecenia w oknie terminala:
# ```
# chmod +x clone_carla.sh
# ./clone_carla.sh
# cd AP-Laboratories/CARLA/
# ```

# %% [markdown]
# **Uwaga!** Wszystkie komendy wykonujemy w katalogu `AP-Laboratories/CARLA/`
#
# Po ściągnięciu plików z repozytorium należy w Visual Studio Code otworzyć skrypt `lab1.ipynb`

# %% [markdown]
# # Uruchomienie środowiska CARLA
#
# W katalogu `AP-Laboratories/CARLA/` wewnątrz repozytorium należy wykonać komendę:
#
# `docker compose up`,
#
# która uruchamia 2 kontenery: **carla** oraz **carla-viz**. Pierwszy z nich to symulator CARLA wraz z GUI, które stanie się widoczne na ekranie. Drugi z nich to narzędzie pozwalające na wizualizację stanu symulacji w przeglądarce.
#
# W razie błędu mówiącego o tym, że nazwa kontenera jest już zajęta, należy usunąć istniejące kontenery:
#
# `docker container rm -f carla_sim carla_viz`

# %% [markdown]
# ## Uruchomienie CarlaViz
# **CarlaViz** to narzędzie webowe służące do wizualizacji symulacji CARLA w czasie rzeczywistym. Umożliwia obserwację symulacji z perspektywy przeglądarki internetowej, niezależnie od głównego okna symulatora.
#
# Aplikacja wyświetla mapę 2D/3D z pozycjami wszystkich aktorów (pojazdów, pieszych, sensorów) oraz pozwala na interaktywną nawigację po scenie. CarlaViz automatycznie łączy się z serwerem CARLA i prezentuje dane telemetryczne pojazdu ego, takie jak prędkość, przyspieszenie czy trajektoria.
#
# Narzędzie jest szczególnie przydatne podczas developmentu algorytmów autonomicznej jazdy, gdyż zapewnia dodatkowy widok "z lotu ptaka" bez obciążania głównego wątku symulacji. CarlaViz obsługuje również wizualizację danych z sensorów, punktów orientacyjnych (waypoints) oraz debug shapes rysowanych przez API CARLA.
#
# CarlaViz uruchamiamy wpisując w przeglądarkę adres: [`http://localhost:8080`](http://localhost:8080).

# %% [markdown]
# ## Przygotowanie środowiska deweloperskiego
#
# Kolejnym krokiem jest przygotowanie środowiska wirtualnego (tzw. virtual environment) Python. Aby uprościć instalację, na potrzeby tego laboratorium zostanie wykorzystane narzędzie Anaconda. Należy uruchomić na komputerze komendę, w nowym oknie terminala w katalogu `AP-Laboratories/CARLA/`:
#
# `conda env list`
#
# która powinna spowodować wylistowanie dostępnych środowisk na kształt poniższego:
#
# ```bash
# lpa8@lpa8:~/ws$ conda env list
# # conda environments:
# #
# base                     /home/lpa8/miniconda3
# aad                      /home/lpa8/miniconda3/envs/aad
# ap-carla-venv            *  /home/lpa8/miniconda3/envs/carla-venv
# ```
#
# W razie, gdyby środowisko carla-venv istniało (jak w przykładzie powyżej), należy pominąć poniższą komendę; w razie jego braku - należy je stworzyć: `conda create -n ap-carla-venv python=3.8.20`.
#
# Następnie powinniśmy zobaczyć znak zachęty z informacją, iż środowisko jest aktywne:
# ```bash
# (ap-carla-venv) lpa8@lpa8:~/ws$
# ```
#
# Prace w ramach tej serii laboratoriów należy wykonywać w tym środowisku.
#
# Środowisko można opuścić za pomocą: `conda deactivate` lub aktywować za pomocą: `conda activate ap-carla-venv`.
#
# **Zainstalowanie zależności:** `pip install -r requirements.txt` (w katalogu `CARLA/` wewnątrz repozytorium).

# %% [markdown]
# ## Przygotowanie kernela Jupyter w środowisku condy
#
# Następnie należy utworzyć konfigurację kernela Jupyter, który będzie korzystał z utworzonego powyżej środowiska wirtualnego condy:`
# ```bash
# python -m ipykernel install --user --name=ap-carla-venv --display-name "Python (ap-carla-venv)"
# ```
#
# ⚠️ **Krytyczne jest** ⚠️, aby wybrać to środowisko w Visual Studio Code. Można to zrobić poprzez aktywowanie okna wyboru klikając w prawym górnym rogu przycisk "Select Kernel", następnie "Jupyter Kernel..." i ostatecznie utworzoną przez nas poprzednio konfigurację "Python (ap-carla-venv)".
#
# ![Opis obrazka](img/s1.png)

# %% [markdown]
# ## Nawiązanie połączenia z CARLA
#
# Aby połączyć się z symulatorem CARLA z API w Pythonie, należy stworzyć instancję `carla.Client`, wskazując adres hosta oraz port, na którym nasłuchuje serwer CARLA. Wykonanie poniższej komórki powinno zakończyć się sukcesem (wypisanie instancji klasy `World`, brak błędu), jeżeli dotychczasowe instrukcje zostały wykonane poprawnie.

# %%
import carla
from time import sleep
import random

client = carla.Client('localhost', 2000)
client.set_timeout(10.0) # ustawienie czasu odpowiedzi serwera (w sek.) - jeżeli CARLA nie odpowie w tym czasie na dowolną z komend, to zostanie zwrócony wyjątek

world = client.get_world()
assert(world is not None)

print(world)
# Out:
# World(id=11346633955819480094)

# %% [markdown]
# ## Sprawdzenie połączenia z CARLA i stanu serwera
# Poprawność połączenia z serwere CARLA można sprawdzić za pomocą następującego kodu:

# %%
try:
    client.get_server_version()
    print(f"✓ Połączenie z CARLA OK - wersja: {client.get_server_version()}")
    print(f"✓ World aktywny: {world.get_map().name}")
except Exception as e:
    print(f"✗ Błąd połączenia z CARLA: {e}")
    print("Upewnij się, że 'docker compose up' jest uruchomiony")
# Out:
# ✓ Połączenie z CARLA OK - wersja: 0.9.15
# ✓ World aktywny: Carla/Maps/Town10HD_Opt

# %% [markdown]
# # Nawigacja kamerą **spectator** w oknie symulacji CARLA
#
# Kamera **spectator** jest niezależnym widokiem na scenę symulacji i służy do swobodnego obserwowania mapy, pojazdów oraz przebiegu eksperymentu.
# **Spektator** w CARLA to wirtualna kamera/obserwator, która kontroluje, co widzisz w oknie symulatora.
#
# Podstawowe zasady sterowania są następujące:
#
# - **W** — ruch kamery do przodu
# - **S** — ruch kamery do tyłu
# - **A** — ruch kamery w lewo
# - **D** — ruch kamery w prawo
# - **Q** — ruch kamery w dół
# - **E** — ruch kamery w górę
#
# Orientacja kamery zmieniana jest myszą:
#
# - przytrzymanie **lewego przycisku myszy** i przeciąganie:
#   - góra/dół — zmiana pochylenia widoku (**pitch**),
#   - lewo/prawo — zmiana obrotu w poziomie (**yaw**). :contentReference[oaicite:2]{index=2}
#
# Widok spectator jest szczególnie przydatny podczas:
# - przeglądania mapy,
# - sprawdzania położenia obiektów i pojazdów,
# - obserwacji efektów zmian w symulacji,
# - wybierania dogodnych punktów startowych dla aktorów.

# %% [markdown]
# # Świat
#
# `World` to główny obiekt służący do zarządzania symulacją w CARLA. Jego instancję pobiera się za pomocą klienta (`client`). Klasa ta nie przechowuje bezpośrednio modelu świata — za reprezentację mapy odpowiada klasa `Map`. Z poziomu obiektu `World` można natomiast uzyskać dostęp do najważniejszych informacji o aktualnym stanie symulacji oraz do jej podstawowych ustawień.
#
# Za pomocą `World` można pobrać między innymi:
#
# * aktorów znajdujących się w symulacji oraz obiekt obserwatora (`spectator`),
# * bibliotekę projektów, inaczej *blueprintów*,
# * mapę,
# * ustawienia symulacji,
# * migawki (`snapshots`) stanu symulacji,
# * ustawienia pogody oraz oświetlenia.
#
# ![Świat](img/WorldDiagram.png)
#
# Do najważniejszych metod klasy `World` należą metody typu *getter*, które umożliwiają pobieranie informacji lub odwołań do wymienionych elementów.
#
# Dostęp do obiektu klasy `World` można uzyskać na kilka sposobów np. z za pomocą metod `.get_world()` lub `.load_world` obiektu klasy `Client`.

# %%
world = client.get_world()
print(f"✓ World aktywny: {world.get_map().name}")
# Out:
# ✓ World aktywny: Carla/Maps/Town10HD_Opt

# %% [markdown]
# ## Mapy
#
# Symulacja w CARLA opiera się na koncepcie mapy. Mapa jest definicją m. in. otoczenia, obiektów oraz dróg. Możliwe jest zarówno listowanie dostępnych map, dodawanie nowych oraz ustawianie konkretnej mapy.

# %%
# Pobranie dostępnych map
available_maps = client.get_available_maps()
for i, map_name in enumerate(available_maps, start=1):
    print(f"{i}.\t{map_name}")
# Out:
# 1.	/Game/Carla/Maps/Town10HD_Opt
# 2.	/Game/Carla/Maps/Town04_Opt
# 3.	/Game/Carla/Maps/Town03_Opt
# 4.	/Game/Carla/Maps/Town02_Opt
# 5.	/Game/Carla/Maps/Town02
# 6.	/Game/Carla/Maps/Town03
# 7.	/Game/Carla/Maps/Town05
# 8.	/Game/Carla/Maps/Town01_Opt
# 9.	/Game/Carla/Maps/Town01
# 10.	/Game/Carla/Maps/Town04
# 11.	/Game/Carla/Maps/Town05_Opt
# 12.	/Game/Carla/Maps/Town10HD

# %% [markdown]
# Do załadowania nowej mapy świata służy metoda: `client.load_world(<nazwa mapay>)` obiektu 'Client`.

# %%
# Przykład załadowania innej mapy
world = client.load_world('Town05_Opt')

# %% [markdown]
# ### Mapy warstwowe
#
# W symulatorze CARLA mamy do dyspozycji mapy które zawierają różne warstwy elementów mapy które można włączać (pokazywać) lub wyłączać (ukrywać). Pozwala to na dobranie odpowiedniego poziomu szczegółowości mapy i jej elementów uwzględniając moc obliczeniową komputera oraz wymagania symulacji.
#
# Nie wszystkie mapy są warstwowe. Dla rozróżnienia która z map posiada a która nie posiada warstw, mapy warstwowe zapisywane są z sufiksem `_Opt` (np. `Town05_Opt`, `Town03_Opt`).
#
# Warstwy map to:
# * NONE (brak warstw)
# * Buildings
# * Decals
# * Foliage
# * Ground
# * ParkedVehicles
# * Particles
# * Props
# * StreetLights
# * Walls
# * All (wszystkie warstwy)
#
# Nazwy poszczególnych warst zdefiniowane są jako atrybutu klasy `MapLayer` a ich lista jest dostępna pod adresm: [https://carla.readthedocs.io/en/0.9.15/python_api/#carla.MapLayer](https://carla.readthedocs.io/en/0.9.15/python_api/#carla.MapLayer)
# Poniżej kod pokazujący w jaki sposób włącząć/wyłączać pojedyńcze warstwy map oraz ich grupy.

# %%
# Toggle all buildings off
world.unload_map_layer(carla.MapLayer.Buildings)

# %%
# Toggle all buildings on
world.load_map_layer(carla.MapLayer.Buildings)

# %%
# Load layered map for Town 05 with minimum layout plus buildings and parked vehicles
world = client.load_world('Town05_Opt', carla.MapLayer.Buildings | carla.MapLayer.ParkedVehicles | carla.MapLayer.StreetLights)

# %%
world.unload_map_layer(carla.MapLayer.All)

# %% [markdown]
# ### Punkty rozmieszczenia
# Oprócz standarodywch elementów mapy zawierają równie *spawn points* tak zwane punkty rozmieszczenia . Dzięki nim można w łatwy sposób rozmieszczać aktorów symulacji (np. samochody, pieszych) `Spawn point`-y służą do łatwego umieszczania aktorów symulacji na mapie.
# Listę `spawn points` można pobrać za pomocą metody `.get_spawn_points()` obiektu `carla.Map`

# %%
spawn_points = world.get_map().get_spawn_points()
print(f"✓ Liczba punktów startowych: {len(spawn_points)}")
print(f"✓ Przykładowy punkt startowy: {spawn_points[0]}")
# Out:
# ✓ Liczba punktów startowych: 302
# ✓ Przykładowy punkt startowy: Transform(Location(x=-44.188328, y=-39.610611, z=0.450000), Rotation(pitch=0.000000, yaw=-90.337494, roll=0.000000))

# %% [markdown]
# CARLA daje również możliwość wygodniej wizualizacji `spawn points`-ów (lub też innych punktów mapy). Do tego celu można wykorzystać specjalne metody do debugowania `carla.DebugHelper` które są częścią klasy `carla.World` [https://carla.readthedocs.io/en/0.9.15/python_api/#carla.DebugHelper](https://carla.readthedocs.io/en/0.9.15/python_api/#carla.DebugHelper)

# %%
# Get the map spawn points
spawn_points = world.get_map().get_spawn_points()

for i, spawn_point in enumerate(spawn_points):
    # Draw in the spectator window the spawn point index
    world.debug.draw_string(spawn_point.location, str(i), life_time=100)
    # We can also draw an arrow to see the orientation of the spawn point
    # (i.e. which way the vehicle will be facing when spawned)
    world.debug.draw_arrow(spawn_point.location, 
                           spawn_point.location + spawn_point.get_forward_vector(), 
                           life_time=100, 
                           color=carla.Color(255, 0, 0))

# %% [markdown]
# W powyższym przykładzie wykorzystano dwie metody klasy `carla.DebugHelper`:
# * `draw_arrow`
# * `draw_string`
# Lista wszystkich metod clasy `carla.DebugHelper` znajduje się pod adresem [(https://carla.readthedocs.io/en/0.9.15/python_api/#methods_12)](https://carla.readthedocs.io/en/0.9.15/python_api/#methods_12)

# %% [markdown]
# ## Pogoda
# W symulatrze CARLA można również zmieniać warunki pogodowe.
# Poniżej znajduje się przykład, jak to zrobić:

# %%
# Crate weather object with specific parameters
weather = carla.WeatherParameters(
    cloudiness=30.0,
    precipitation=10.0,
    sun_altitude_angle=90.0, 
    fog_density=0.0)

# Apply weather parameters to the world
world.set_weather(weather)

# %% [markdown]
# Lista wszystkich dostępnych opcji pogody znajduje się pod adres [https://carla.readthedocs.io/en/0.9.15/python_api/#carla.WeatherParameters](https://carla.readthedocs.io/en/0.9.15/python_api/#carla.WeatherParameters)
#
# - **`cloudiness` (`float`)**
#   Określa stopień zachmurzenia. Przyjmuje wartości od `0` do `100`, gdzie `0` oznacza całkowicie bezchmurne niebo, a `100` całkowite zachmurzenie.
#
# - **`precipitation` (`float`)**
#   Określa intensywność opadów deszczu. Przyjmuje wartości od `0` do `100`, gdzie `0` oznacza brak opadów, a `100` bardzo intensywny deszcz.
#
# - **`precipitation_deposits` (`float`)**
#   Określa poziom tworzenia się kałuż. Przyjmuje wartości od `0` do `100`, gdzie `0` oznacza brak kałuż, a `100` drogę całkowicie pokrytą wodą. Kałuże są generowane w stałych miejscach.
#
# - **`wind_intensity` (`float`)**
#   Określa siłę wiatru. Przyjmuje wartości od `0` do `100`, gdzie `0` oznacza brak wiatru, a `100` silny wiatr. Wiatr wpływa na kierunek deszczu oraz ruch liści na drzewach.
#
# - **`sun_azimuth_angle` (`float`, stopnie)**
#   Określa kąt azymutu słońca. Przyjmuje wartości od `0` do `360`. Wartość `0` odpowiada punktowi odniesienia zdefiniowanemu w Unreal Engine.
#
# - **`sun_altitude_angle` (`float`, stopnie)**
#   Określa wysokość słońca nad horyzontem. Przyjmuje wartości od `-90` do `90`, co odpowiada odpowiednio północy i południu.
#
# - **`fog_density` (`float`)**
#   Określa gęstość mgły. Wpływa jedynie na obraz z kamery RGB. Przyjmuje wartości od `0` do `100`.
#
# - **`fog_distance` (`float`, metry)**
#   Określa odległość, od której zaczyna być widoczna mgła. Przyjmuje wartości od `0` do nieskończoności.
#
# - **`wetness` (`float`)**
#   Określa stopień zawilgocenia sceny. Wpływa jedynie na obraz z kamery RGB. Przyjmuje wartości od `0` do `100`.
#
# - **`fog_falloff` (`float`)**
#   Określa sposób zmiany gęstości mgły wraz z wysokością. Przyjmuje wartości od `0` do nieskończoności. Im większa wartość, tym mgła jest gęstsza i utrzymuje się bliżej podłoża.
#   - `0` — mgła rozciąga się na całą scenę,
#   - `1` — mgła ma gęstość zbliżoną do powietrza i sięga wysokości typowych budynków,
#   - wartości większe niż `5` — mgła staje się bardzo gęsta przy powierzchni gruntu.
#
# - **`scattering_intensity` (`float`)**
#   Określa, jak silnie światło wpływa na objętościową mgłę. Wartość `0` oznacza brak tego efektu.
#
# - **`mie_scattering_scale` (`float`)**
#   Określa oddziaływanie światła z dużymi cząstkami, takimi jak pyłki lub zanieczyszczenia powietrza. Efektem może być zamglone niebo i poświata wokół źródeł światła. Wartość `0` oznacza brak tego efektu.
#
# - **`rayleigh_scattering_scale` (`float`)**
#   Określa oddziaływanie światła z małymi cząstkami, takimi jak cząsteczki powietrza. Odpowiada za efekty takie jak niebieskie niebo w dzień lub czerwone niebo wieczorem.
#
# - **`dust_storm` (`float`)**
#   Określa siłę burzy pyłowej. Przyjmuje wartości od `0` do `100`.

# %% [markdown]
# ## Blueprint
#
# [**Blueprint**](https://en.wikipedia.org/wiki/Blueprint) w CARLA to gotowy **wzorzec obiektu**, na podstawie którego można utworzyć aktora w świecie symulacji.
# Można o nim myśleć jak o **szablonie** lub **opisie obiektu**, który określa:
#   - **jaki typ obiektu** ma zostać utworzony,
#   - **do jakiej kategorii** należy ten obiekt,
#   - **jakie ma właściwości i parametry**.
#
# W praktyce blueprint nie jest jeszcze obiektem istniejącym w symulacji.
# Jest to jedynie **definicja**, z której dopiero można utworzyć właściwego aktora.
# Dopiero po użyciu blueprintu i wywołaniu odpowiedniej metody tworzenia obiektu w świecie CARLA powstaje rzeczywisty aktor, np. pojazd, pieszy albo sensor.
#
# Blueprinty są przechowywane w **bibliotece blueprintów** (*Blueprint Library*), która zawiera wszystkie wzorce obiektów dostępnych w danej wersji symulatora.
# Z poziomu programu można pobrać tę bibliotekę i przeszukiwać ją w celu znalezienia odpowiedniego blueprintu. Listę dostępnych w symulatorze blueprintów można znaleźć pod adresem: [https://carla.readthedocs.io/en/0.9.15/catalogue_props/](https://carla.readthedocs.io/en/0.9.15/catalogue_props/)
#
# W bibliotece blueprintów znajdują się między innymi wzorce:
#   - **pojazdów**,
#   - **pieszych**,
#   - **kamer**,
#   - **LiDAR-ów**,
#   - **radarów**,
#   - **czujników kolizji**,
#   - **sygnalizatorów świetlnych**,
#   - **znaków drogowych**,
#   - innych elementów sceny.
#
# Każdy blueprint posiada własny **identyfikator** (*ID*), który jednoznacznie określa jego typ.
# Identyfikator ten jest zwykle zapisany w formie tekstowej, na przykład w postaci opisującej kategorię i konkretny model obiektu.
# Dzięki temu można łatwo wyszukać interesujące blueprinty, np. tylko pojazdy albo tylko sensory.
#
# Blueprint zawiera również **atrybuty**, czyli parametry opisujące dany obiekt.
# Atrybuty mogą określać na przykład:
#   - nazwę lub typ obiektu,
#   - jego wariant,
#   - kolor,
#   - rolę w symulacji,
#   - ustawienia wybranego sensora,
#   - inne cechy konfiguracyjne zależne od rodzaju obiektu.
#
# Część atrybutów można zmieniać jeszcze **przed utworzeniem aktora**.
# Oznacza to, że najpierw wybieramy odpowiedni blueprint, następnie ustawiamy jego wybrane właściwości, a dopiero potem tworzymy obiekt w symulacji.
# Dzięki temu można przygotować różne wersje obiektów bez konieczności ręcznego definiowania ich od podstaw.
#
# Przykładowo:
#   - wybierając blueprint pojazdu, można utworzyć konkretny model samochodu,
#   - wybierając blueprint kamery, można dodać sensor rejestrujący obraz,
#   - wybierając blueprint pieszego, można dodać uczestnika ruchu do sceny.
#
# Blueprinty są bardzo ważne w pracy z CARLA, ponieważ stanowią **punkt wyjścia do tworzenia większości obiektów w symulacji**.
# Bez wybrania odpowiedniego blueprintu nie można utworzyć aktora.
# Można więc powiedzieć, że blueprint jest **opisem obiektu**, a aktor jest **rzeczywistym obiektem utworzonym na podstawie tego opisu**.
#
# Poniższy kod wyświetla wszystkie dostępne w symulatorze CARLA **blueprint-y**:

# %%
for i, blueprint in enumerate(world.get_blueprint_library())   :
   print(f'{i}: {blueprint.id}')
   for attr in blueprint:
       print('  - {}'.format(attr))
# Out:
# 0: static.trigger.friction
#   - ActorAttribute(id=extent_y,type=float,value=1)
#   - ActorAttribute(id=extent_z,type=float,value=1)
#   - ActorAttribute(id=extent_x,type=float,value=1)
#   - ActorAttribute(id=friction,type=float,value=3.5)
#   - ActorAttribute(id=ros_name,type=str,value=static.trigger.friction)
#   - ActorAttribute(id=role_name,type=str,value=default)
# 1: static.prop.warningaccident
#   - ActorAttribute(id=size,type=str,value=medium(const))
#   - ActorAttribute(id=ros_name,type=str,value=static.prop.warningaccident)
#   - ActorAttribute(id=role_name,type=str,value=prop)
# 2: static.prop.doghouse
#   - ActorAttribute(id=size,type=str,value=small(const))
#   - ActorAttribute(id=ros_name,type=str,value=static.prop.doghouse)
#   - ActorAttribute(id=role_name,type=str,value=prop)
# 3: static.prop.travelcase
#   - ActorAttribute(id=size,type=str,value=small(const))
#   - ActorAttribute(id=ros_name,type=str,value=static.prop.travelcase)
# ...

# %% [markdown]
# Listę dostępnych **blueprint-ów** można filtorwać z wykorzystaniem metody `.filter(...)`. Poniższy kod wyświetla np. listę wszystkich dostępnych sensorów typu kamera.

# %%
for i, blueprint in enumerate(world.get_blueprint_library().filter('sensor.camera.*'))   :
   print(f'{i}: {blueprint.id}')
   for attr in blueprint:
       print('  - {}'.format(attr))
# Out:
# 0: sensor.camera.depth
#   - ActorAttribute(id=lens_y_size,type=float,value=0.08)
#   - ActorAttribute(id=lens_kcube,type=float,value=0)
#   - ActorAttribute(id=lens_circle_multiplier,type=float,value=0)
#   - ActorAttribute(id=lens_circle_falloff,type=float,value=5)
#   - ActorAttribute(id=lens_k,type=float,value=-1)
#   - ActorAttribute(id=fov,type=float,value=90)
#   - ActorAttribute(id=image_size_y,type=int,value=600)
#   - ActorAttribute(id=image_size_x,type=int,value=800)
#   - ActorAttribute(id=sensor_tick,type=float,value=0)
#   - ActorAttribute(id=lens_x_size,type=float,value=0.08)
#   - ActorAttribute(id=ros_name,type=str,value=sensor.camera.depth)
#   - ActorAttribute(id=role_name,type=str,value=front)
# 1: sensor.camera.normals
#   - ActorAttribute(id=lens_y_size,type=float,value=0.08)
#   - ActorAttribute(id=lens_kcube,type=float,value=0)
#   - ActorAttribute(id=lens_circle_multiplier,type=float,value=0)
#   - ActorAttribute(id=lens_circle_falloff,type=float,value=5)
# ...

# %% [markdown]
# ## Aktor
# **Aktor** (*actor*) to podstawowy obiekt występujący w świecie symulacji CARLA.
# Można powiedzieć, że aktor to każda „rzecz”, która istnieje w symulacji i z którą możemy w jakiś sposób pracować.
# Aktorami są między innymi:
#   - **pojazdy**,
#   - **piesi**,
#   - **sensory** (np. kamery, LiDAR, radar),
#   - **znaki drogowe**,
#   - **sygnalizatory świetlne**,
#   - **spectator**, czyli kamera obserwatora.
#
# Aktor jest podstawową jednostką, na której wykonuje się operacje w CARLA.
# W praktyce oznacza to, że dla aktora możemy na przykład:
#   - utworzyć go w symulacji,
#   - odczytać jego położenie i orientację,
#   - zmieniać jego stan,
#   - sterować jego ruchem,
#   - usuwać go ze świata symulacji.
#
# Aktorzy są tworzeni na podstawie tzw. [**blueprintów**](https://en.wikipedia.org/wiki/Blueprint), czyli gotowych wzorców opisujących typ obiektu i jego właściwości.
# Dzięki temu można łatwo utworzyć w symulacji np. wybrany model samochodu, pieszego lub konkretny sensor.
#
# Zrozumienie pojęcia **aktora** jest bardzo ważne, ponieważ większość operacji wykonywanych w CARLA dotyczy właśnie pracy z aktorami.

# %% [markdown]
# ### Dodawanie aktora
#
# Dodanie aktora (*spawning an actor*) polega na utworzeniu nowego obiektu w świecie symulacji.
#
# Aby dodać aktora w CARLA, potrzebne są trzy elementy:
#   - obiekt świata symulacji `World`,
#   - odpowiedni **blueprint**, czyli wzorzec obiektu,
#   - **transformacja** (`Transform`), która określa położenie i orientację obiektu.
#
# W praktyce proces dodawania aktora wygląda zwykle następująco:
#   - pobranie obiektu `world`,
#   - pobranie biblioteki blueprintów,
#   - wybór blueprintu odpowiedniego obiektu,
#   - wybór miejsca dodania obiektu,
#   - utworzenie aktora za pomocą metody `spawn_actor()` lub `try_spawn_actor()`.
#
# Dla samochodów i rowerów najczęściej wykorzystuje się gotowe punkty startowe dostępne na mapie (zobacz punkt **Punkty rozmieszczenia**).
# Dla pieszych wygodnie jest używać losowych lokalizacji na chodniku.
#
# Metoda `.spawn_actor()` obiektu `World` zgłasza wyjątek, jeśli nie uda się utworzyć obiektu.
# Metoda `.try_spawn_actor()` obiektu `World`  jest bezpieczniejsza w prostych skryptach, ponieważ w przypadku niepowodzenia zwraca `None`.
#
# Po dodaniu aktora można:
#   - odczytać jego położenie,
#   - sterować nim (jeśli aktor ma taką możliwość),
#   - dołączać do niego sensory,
#   - usuwać go ze świata symulacji.
#
# W przypadku pieszego samo dodanie aktora tworzy obiekt w świecie, ale nie musi jeszcze oznaczać ruchu.
# Aby pieszy zaczął się poruszać, zwykle tworzy się dodatkowo kontroler `WalkerAIController`.
#
# Kod poniżej dodaje aktora `vendding machine` do symulacji i umieszcza go w punkcie `spawn_point` o indeksie 203.

# %%
actor_bp = world.get_blueprint_library().filter('static.prop.vendingmachine')[0]
actor_vendingmachine = world.try_spawn_actor(actor_bp, world.get_map().get_spawn_points()[203])
if actor_vendingmachine is not None:
    print("Utoworzono i dodano do symulacji aktora")
else:
    print("Nie udało się utworzyć aktora!")
# Out:
# Utoworzono i dodano do symulacji aktora

# %% [markdown]
# Do usuwania aktorów służy metoda `.destroy()` obiektu klasy `

# %%
if actor_vendingmachine.is_alive:
        actor_vendingmachine.destroy()
        print("Usunięto aktora")

# %% [markdown]
# ### Odczytywanie i filtrowanie listy aktorów
#
# API umożliwia odczyt aktorów przez metodę klasy `World.get_actors()`, która zwraca listę **istniejących obiektów (aktorów) już obecnych w symulacji** - to są konkretne instancje pojazdów, pieszych, sensorów itp., które zostały już utworzone i działają w świecie CARLA. Rezultat jej działania jest iterowalny, ale też pozwala na filtrowanie przez wywołanie metody `.filter('...')`. Argumentem jest wyrażenie przypominające [glob](https://en.wikipedia.org/wiki/Glob_(programming)):

# %%
# Pobranie listy wszystkich aktorów typu traffic.traffic_light w symulacji
actors = world.get_actors().filter('traffic.traffic_light')

# Wyświetlenie pierwszych 10 informacji o wszystkich aktorach
for actor in list(actors)[:10]:
    print(f'Aktor: {actor.type_id}, ID: {actor.id}, Role name: {actor.attributes.get("role_name", "N/A")}')
# Out:
# Aktor: traffic.traffic_light, ID: 251, Role name: N/A
# Aktor: traffic.traffic_light, ID: 250, Role name: N/A
# Aktor: traffic.traffic_light, ID: 249, Role name: N/A
# Aktor: traffic.traffic_light, ID: 248, Role name: N/A
# Aktor: traffic.traffic_light, ID: 247, Role name: N/A
# Aktor: traffic.traffic_light, ID: 246, Role name: N/A
# Aktor: traffic.traffic_light, ID: 245, Role name: N/A
# Aktor: traffic.traffic_light, ID: 244, Role name: N/A
# Aktor: traffic.traffic_light, ID: 243, Role name: N/A
# Aktor: traffic.traffic_light, ID: 242, Role name: N/A

# %% [markdown]
# Możliwość odczytywania listy aktórów i filtrowania ich po typie pozwala np. na szybkie usuwanie aktorów z symulacji.

# %%
for actor in world.get_actors().filter('vehicle.*'):
    if actor.is_alive:
        actor.destroy()

# %% [markdown]
# ### Dodawanie pojazdu do symulacji
# W symulatorze CARLA mamy zdefiniowanych prawie 40 różnych modeli samochodów, dla których możemy dodatkowo konfigurować różne inne parametry. Chcąc dodać pojazd do symulacji musimy wybrać "projekt" naszego samochodu. Listę wszystkich dostępnych "projektów" samochodów możemy odczytać metodą `get_blueprint_library()` klasy `World` w połączeniu z metodą `.filter('...')`

# %%
available_vehicles_bp = world.get_blueprint_library().filter('vehicle.*')
print(f'Liczba dostępnych typów pojazdów: {len(available_vehicles_bp)}')

vehicle_bp = random.choice(available_vehicles_bp)
print(f'Wybrany losowo model pojazdu: {vehicle_bp.id}')
# Out:
# Liczba dostępnych typów pojazdów: 41
# Wybrany losowo model pojazdu: vehicle.toyota.prius

# %% [markdown]
# Samochód oraz innych aktorów symulacji umieszczamy na wybranej mapie, podając współrzędne miejsca. Symulator CARLA dla każdej mapy definiuje listę predefiniowanych punktów, w których można ich umieszczać. Listę predefiniowanych współrzędnych tzw. "spawn_points" można odczytać za pomocą metody `.get_spawn_points()` klasy `carla.Map()`

# %% [markdown]
# #### Pojazd EGO
# Przed dodaniem pojazdu do symulacji warto ustawić mu atrybut 'ego'.
# **Ego vehicle** to **główny pojazd** w symulacji - ten, którym sterujemy lub który obserwujemy. W kontekście autonomicznych pojazdów to "nasz" pojazd, z którego perspektywy działa system. Pojazd ego w symulacji ma dodatkowe funkcje/właściwości:
# 1. **Identyfikacja** - wyróżnia główny pojazd spośród innych (NPC, traffic)
# 2. **CarlaViz** - narzędzie wyświetla dodatkowe wskaźniki tylko dla ego
# 3. **Sensory** - zazwyczaj sensory (kamery, lidary) montuje się na ego vehicle
# 4. **Algorytmy** - systemy percepcji i planowania działają z perspektywy ego
#
# W symulacji może być wiele pojazdów, ale zazwyczaj jeden jest oznaczony jako **ego** - ten, który jest celem naszej analizy lub sterowania.
#
# Do ustawienia właściwości **ego** służy metoda `set_attribute('role_name', 'ego')` wywoływana na obiekcie pojazdu.

# %%
vehicle_bp.set_attribute('role_name', 'ego')
vehicle_ego = world.try_spawn_actor(vehicle_bp, world.get_map().get_spawn_points()[202])
if vehicle_ego is not None:
    print("Utoworzono i dodano do symulacji pojazd EGO")
else:
    print("Nie udało się utworzyć pojazdu EGO!")
# Out:
# Utoworzono i dodano do symulacji pojazd EGO

# %% [markdown]
# Zmienna `vehicle` wskazuje na obiekt naszego pojazdu. Za jej pomocą możemy kontrolować zachowanie naszego pojazdu, odczytywać jego parametry oraz dane z sensorów pojazdu.

# %% [markdown]
# #### Aktor NPC
# **NPC** to skrót od **Non-Player Character** co można przetłumaczyć jako
# **postać niezależna** lub **postać niekierowana przez gracza**
# To każda postać w grze lub symulacji, która nie jest bezpośrednio sterowana przez użytkownika, tylko przez:
# * logikę gry,
# * skrypt,
# * sztuczną inteligencję,
# * gotowe reguły zachowania.
#
# Na przykłady:
# * przechodzień na ulicy,
# * sprzedawca w sklepie,
# * przeciwnik patrolujący teren,
# * inni uczestnicy ruchu w symulatorze.
#
# W kontekście symulatora CARLA pojęcie **NPC** zwykle odnosi się do:
# * pojazdów sterowanych automatycznie,
# * pieszych,
# * innych aktorów poruszających się według reguł symulacji, a nie ręcznie przez użytkownika.
#
# Poniższy kod dodaje 10 losowych pojazdów (NPC) do symulacji.

# %%
try:
    for vehicle in vehicle_npc:
        if vehicle.is_alive:
            vehicle.destroy()
except NameError:
    vehicle_npc = []
    
for vehicle_bp in random.sample(list(world.get_blueprint_library().filter('vehicle.*')), 10):
    vehicle = world.try_spawn_actor(vehicle_bp, random.choice(world.get_map().get_spawn_points()))
    if vehicle is not None:
        vehicle_npc.append(vehicle)

# %% [markdown]
# ## Autopilot
# W symulatorze CARLA można dla **dowolnego** pojazdu włączyć tryb jazdy autonomicznej. Aby to zrobić, należy użyć metody `.set_autopilot(True)` na obiekcie klasy `Vehicle`, którą należy wywołać z okna terminala (**nie skryptu Jupyter!**). W oknie terminala, z aktywnym środowiskiem `ap-carla-venv` należy wpisać `python` i skopiować oraz wkleić poniższy kod (w oknie terminala wklejamy skopiowany tekst komendą Ctrl+Shift+V):
#
# ```
# import carla
#
# client = carla.Client('localhost', 2000)
# client.set_timeout(10.0) # ustawienie czasu odpowiedzi serwera (w sek.) - jeżeli CARLA nie odpowie w tym czasie na dowolną z komend, to zostanie zwrócony wyjątek
#
# world = client.get_world()
#
# vehicle = next((v for v in world.get_actors().filter('vehicle.*') if v.attributes.get('role_name') == 'ego'), None)
# ```
#
# Zmienna `vehicle` wskazuje na nasz pojazd **ego**. Jeśli chcemy, aby rozpoczął jazdę autonomiczną, należy w oknie terminala wpisać:
# ```
# vehicle.set_autopilot(True)
# ```
#
# Podobnie, jeśli chcemy zatrzymać tryb jazdy autonomicznej:
# ```
# vehicle.set_autopilot(False)
# ```

# %%
vehicle_ego.set_autopilot(True)
for vehicle in vehicle_npc:
    vehicle.set_autopilot(True)

# %% [markdown]
# Po włączeniu trybu jazdy `autopilot` można śledzić sposób poruszania się pojazdu `ego` w `CarlaViz`. W tym celu należy otworzyć w przeglądarce adres [http://localhost:8080](http://localhost:8080). Po lewej stronie wyświetlane są podstawowe parametry pojazdu `ego`, takie jak prędkość i przyspieszenie. Można również wybrać widok z wnętrza pojazdu `ego` (`View Mode -> Driver`).
#
# ![DriverMode](img/cv1.png)
#
# Jeśli chcemy zatrzymać automatyczną jazdę pojazdów dodanych do symulacji, należy dla każdego z nich wywołać metodę `.set_autopilot(False)`.

# %%
vehicle_ego.set_autopilot(False)
for vehicle in vehicle_npc:
    vehicle.set_autopilot(False)

# %% [markdown]
# **Uwaga!** W przypadku pojazdu typu **ego** wywołanie metody `.set_autopilot(False)` powoduje zatrzymanie aktualizacji sygnałów sterowania pojazdem, takich jak przepustnica i kąt skrętu kół. W rezultacie po pewnym czasie pojazd może zderzyć się z innymi aktorami symulacji, a nawet opuścić obszar symulowanego świata.

# %% [markdown]
# ## Dodanie sensora (kamery) do pojazdu
# W CARLA kamerę dodaje się jako sensor przyłączony do pojazdu przez metodę `spawn_actor()` z odpowiednim parametrem `attach_to`. Najpierw wybieramy rodzaj sensora (kamera) metodą `world.get_blueprint_library().find('sensor.camera.rgb')`. Następnym krokiem jest ustawienie miejsca, w którym kamera jest zamontowana (`carla.Transform`). Na końcu trzeba dodać utworzony sensor (kamerę) do wybranego pojazdu (np. ego) za pomocą `world.spawn_actor()`.
#
# Przykładowy kod dodający kamerę RGB zamieszczony jest poniżej.
#
# Po dodaniu kamery zaobserwuj jej działanie w programie CarlaViz.

# %%
# 1. Blueprint kamery
camera_bp = world.get_blueprint_library().find('sensor.camera.rgb')
camera_bp.set_attribute('image_size_x', '1920')
camera_bp.set_attribute('image_size_y', '1080')
camera_bp.set_attribute('fov', '110')

# 2. Pozycja montażu (widok z kokpitu)
camera_transform = carla.Transform(
    carla.Location(x=2.5, y=0.0, z=1.4),
    carla.Rotation(pitch=0, yaw=0, roll=0)
)

# 3. Spawn kamery
camera = world.spawn_actor(camera_bp, camera_transform, attach_to=vehicle_ego)

print(f'Kamera dodana do pojazdu: {camera.type_id}')

# %% [markdown]
# ## Ustawienie pozycji spektatora
#
# W Python API do obiektu spectator można uzyskać dostęp przez: `world.get_spectator()`.
# Pozwala to odczytać jego aktualne położenie i orientację lub programowo ustawić nowy widok kamery.
#
# **Ważne:** Spektator to tylko kamera - nie wpływa na fizykę symulacji, nie ma kolizji, może przenikać przez obiekty.

# %%
def set_spectator_for_vehicle(world, vehicle):
    """Positions the spectator camera behind the specified vehicle."""
    spectator = world.get_spectator()
    transform = vehicle.get_transform()
    # Get the forward vector to calculate the offset relative to the vehicle's orientation
    forward_vector = transform.get_forward_vector()

    # Calculate offset: -15 meters back, 6 meters up
    offset = carla.Location(x=-10 * forward_vector.x, y=-15 * forward_vector.y, z=6)
    # Calculate the new spectator transform
    spectator_transform = carla.Transform(
        transform.location + offset,
        # Set rotation: slightly looking down (-20 pitch), same yaw as vehicle
        carla.Rotation(pitch=-20, yaw=transform.rotation.yaw, roll=transform.rotation.roll)
    )
    # Wrap the set_transform call in a try-except block for robustness
    try:
        spectator.set_transform(spectator_transform)
    except Exception as e:
        print(f"Error setting spectator transform: {e}")

# %%
set_spectator_for_vehicle(world, vehicle_ego)
# Out:
# Spectator camera positioned behind the vehicle.

# %% [markdown]
# Zaobserwuj jazdę samochodu w programie CarlaViz.

# %% [markdown]
# ## Śledzenie ruchu pojazdu w symulatorze
# Aby śledzić ruch pojazdu w symulatorze, musimy aktualizować pozycję spektatora w pętli, synchronizując ją z pozycją poruszającego się pojazdu.

# %%
try:
    while True:
        world.wait_for_tick()
        set_spectator_for_vehicle(world, vehicle_ego)
except KeyboardInterrupt:
    print("Przerwano śledzenie")
finally:
    pass
# Out:
# Przerwano śledzenie

# %% [markdown]
# # Zadanie do wykonania
# Dodaj 20 innych pojazdów, dla każdego z pojazdów ustaw tryb jazdy autonomicznej. Zaobserwuj ruch dodanych pojazdów z widoku z "góry" - kamera obserwatora nie podąża za pojazdem ego.
#
# **Uwaga!** Pamiętaj, aby tryb jazdy autonomicznej dla pojazdów włączać z terminala, a nie ze skryptu Jupyter.

# %%
# Usunięcie istniejących pojazdów
for vehicle in world.get_actors().filter('vehicle.*'):  
    vehicle.destroy()
    
# TODO
...

# %% [markdown]
# ## Sterowanie ręczne pojazdem
#
# Klasa `carla.VehicleControl` to klasa definiująca polecenia sterowania pojazdem. Reprezentuje stan "wirtualnego kierowcy" - pozycje pedałów i kierownicy.
# ```
# carla.VehicleControl(
#     throttle=0.0,      # Gaz: 0.0-1.0 (0%=brak, 1.0=100%)
#     steer=0.0,         # Kierownica: -1.0 do 1.0 (-1=maksymalnie w lewo, +1=maksymalnie w prawo, 0=prosto)
#     brake=0.0,         # Hamulec: 0.0-1.0 (0%=brak, 1.0=100%)
#     hand_brake=False,  # Hamulec ręczny: True/False
#     reverse=False,     # Bieg wsteczny: True/False
#     manual_gear_shift=False,  # Ręczna zmiana biegów: True/False
#     gear=0             # Numer biegu (jeśli manual_gear_shift=True)
# )
# ```
# Podstawowe użycie:
# 1. Jazda prosto z pełnym gazem:
# ```
# control = carla.VehicleControl(throttle=1.0, steer=0.0)
# vehicle.apply_control(control)
# sleep(2)
# ```
#
# 2. Skręt w lewo z połową gazu:
# ```
# control = carla.VehicleControl(throttle=0.5, steer=-0.5)
# vehicle.apply_control(control)
# sleep(2)
# ```
# 3. Hamowanie:
# ```
# control = carla.VehicleControl(throttle=0.0, brake=1.0)
# vehicle.apply_control(control)
# sleep(2)
# ```
#
# 4. Cofanie:
# ```
# control = carla.VehicleControl(throttle=0.5, reverse=True)
# vehicle.apply_control(control)
# sleep(2)
# ```
#
# 5. Hamulec ręczny:
# ```
# control = carla.VehicleControl(hand_brake=True)
# vehicle.apply_control(control)
# sleep(2)
# ```
#
# 6. Zatrzymanie
# ```
# vehicle.apply_control(carla.VehicleControl())
# ```
#
# **Uwaga!**
# * Wartości nie są trwałe - musisz ciągle wysyłać komendy w pętli
# * `throttle` i `brake` się wykluczają - używaj jednego naraz
# * W trybie synchronicznym (world.tick()) sterowanie jest bardziej precyzyjne
# * Autopilot (`set_autopilot(True)`) przejmuje kontrolę - wyłącz go przed ręcznym sterowaniem

# %%
# Usunięcie istniejących pojazdów
for vehicle in world.get_actors().filter('vehicle.*'):  
    vehicle.destroy()

# TODO: dodaj pojazd do symulacji
# https://carla.readthedocs.io/en/latest/python_api/#carla.World.spawn_actor
vehicle = ...

set_spectator_for_vehicle(world, vehicle)


# Ustawienie ręcznego sterowania
vehicle.apply_control(carla.VehicleControl(throttle=1, steer=0.0))  # Przyspieszenie 100%, brak skrętu

# TODO: przez 10s jedź, potem zatrzymaj pojazd
# ...

# https://carla.readthedocs.io/en/latest/python_api/#carla.VehicleControl.brake
# ... # ustaw hamowanie na 100%

# %% [markdown]
# ## Interaktywne sterowanie
#
# Zrealizuj interaktywne sterowanie w pliku [`manual-control.py`](./manual-control.py).
#
# Uruchom skrypt korzystając z `python manual-control.py`.
